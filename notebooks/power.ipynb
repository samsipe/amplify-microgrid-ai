# %%
import numpy as np
import pandas as pd

data = pd.read_csv('./Capital_Flats_2021-12-01_14_20_34.csv', header=[0,1], low_memory=False) 
data.head(20)
# Out:
# /opt/anaconda3/envs/fourthbrain/lib/python3.8/site-packages/pandas/util/_decorators.py:311: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   return func(*args, **kwargs)
#      Unnamed: 0_level_0              PowerScout DPS100  \
#               Timestamp Calculated True Energy 1 (kWh)
# 0   2021-11-30 23:59:00                          0.000
# 1   2021-11-30 23:58:00                          0.000
# 2   2021-11-30 23:57:00                          0.000
# 3   2021-11-30 23:56:00                          0.000
# 4   2021-11-30 23:55:00                          0.000
# 5   2021-11-30 23:54:00                          0.000
# 6   2021-11-30 23:53:00                          0.000
# 7   2021-11-30 23:52:00                          0.000
# 8   2021-11-30 23:51:00                          0.000
# 9   2021-11-30 23:50:00                          0.000
# 10  2021-11-30 23:49:00                          0.000
# ...
